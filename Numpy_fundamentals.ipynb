# %% [markdown]
# Creating Numpy Arrays

# %%
## np.array
import numpy as np

a = np.array([1, 2, 3])

print(type(a))

print(a)

# %%
## 2d and 3d

b = np.array([[1, 2, 3], [4, 5, 6]])
print(b)

# %%
c = np.array([[[1, 2], [3, 4], [5, 6], [7, 8]]])
print(c)

# %%
## dtype

np.array([1, 2, 3], dtype= float)

# %%
np.array([1, 2, 3], dtype=bool)

# %%
np.array([1, 2, 3], dtype=complex)

# %%
## np.arange

np.arange(1, 11)

# %%
np.arange(1, 11, 2)

# %%
## with reshape

np.arange(1, 11).reshape(5, 2)

# %%
np.arange(1, 11).reshape(2, 5)

# %%
## np.ones and np.zeros

np.ones((3, 4))

# %%
np.zeros((3, 4))

# %%
## np.random

np.random.random((3, 4))

# %%
## np.linspace

np.linspace(-10, 10, 10)

# %%
## np.identity

np.identity(3)

# %%
import numpy as np
a1 = np.arange(10)
a2 = np.arange(12, dtype=float).reshape(3, 4)
a3 = np.arange(8).reshape(2, 2, 2)

print(a1)
print('\n')
print(a2)
print('\n')
print(a3)

# %%
## ndim - it tells no. of dimensions

a1.ndim

# %%
a2.ndim

# %%
a3.ndim

# %%
## shape - how much item in every dimensions

a1.shape

# %%
a2.shape

# %%
a3.shape

# %%
## size - no. of items

print(a1.size)
print(a2.size)
print(a3.size)

# %%
## itemsize - memory occupation size

print(a1.itemsize)
print(a2.itemsize)
print(a3.itemsize)

# %%
## dtype it tells data type

print(a1.dtype)
print(a2.dtype)
print(a3.dtype)

# %% [markdown]
# Changing Datatype

# %%
## astype

a3.astype('int32')

# %% [markdown]
# Array Opeartions

# %%
a1 = np.arange(12).reshape(3, 4)
a2 = np.arange(12, 24).reshape(3, 4)

print(a1)
print('\n')
print(a2)

# %%
## Scaler operations

## Arithemetic
a1 * 2

# %%
a1 + 2

# %%
a1 ** 2

# %%
## Relational operators
a2 > 5

# %%
a2 == 15

# %%
## Vector opeartions = 2 numpy array operations

## Arithmetic operations

a1 + a2

# %%
a1 / a2

# %% [markdown]
# Array Functions

# %%
a1 = np.random.random((3, 3))
a1 = np.round(a1*100)

a1

# %%
## max/min/sum/prod

np.max(a1)

# %%
np.min(a1)

# %%
np.sum(a1)

# %%
np.prod(a1)

# %%
## 0 -> col and 1 -> row

np.max(a1, axis=1)

# %%
np.max(a1, axis=0)

# %%
np.sum(a1, axis=1)

# %%
## mean/median/std/var

np.mean(a1)

# %%
np.mean(a1, axis=1)

# %%
np.median(a1)

# %%
np.std(a1)

# %%
np.var(a1)

# %%
## Trignometric functions

np.sin(a1)

# %%
## Dot product

a2 = np.arange(12).reshape(3, 4)
a3 = np.arange(12, 24).reshape(4, 3)

np.dot(a2, a3)

# %%
## log and exponents

np.log(a1)

# %%
np.exp(a1)

# %%
## round/floor/ceil

np.round(np.random.random((2, 3))*100)

# %%
np.floor(np.random.random((2, 3))*100)

# %%
np.ceil(np.random.random((2, 3))*100)

# %% [markdown]
# Indexing and Slicing

# %%
import numpy as np

a1 = np.arange(10)
a2 = np.arange(12).reshape(3, 4)
a3 = np.arange(8).reshape(2, 2, 2)

print(a1)
print()
print(a2)
print()
print(a3)

# %%
a1

# %%
## indexing
a1[-1]

# %%
a1[0]

# %%
a2

# %%
a2[1][2]

a2[1, 2]

# %%
a2[2, 3]

# %%
a2[1, 0]

# %%
a3

# %%
a3[1, 0, 1]

# %%
a3[0, 1, 0]

# %%
a3[0, 0, 0]

# %%
a3[1, 1, 0]

# %%
## Slicing - multiple item fetch

a1

# %%
a1[2 : 5]

# %%
a1[2 : 5 : 2]

# %%
a2

# %%
a2[0, :]

# %%
a2[:, 2]

# %%
a2[1:, 1 : 3]

# %%
a2[::2, ::3]

# %%
a2

# %%
a2[::2, 1::2]

# %%
a2[1, ::3]

# %%
a2

# %%
a2[0:2, 1:]

# %%
a3

# %%
a3 = np.arange(27).reshape(3, 3, 3)
a3

# %%
a3[1]

# %%
a3[::2]

# %%
a3[0, 1,:]
a3[0, 1]

# %%
a3[1, :,1]

# %%
a3[2, 1:, 1:]

# %%
a3

# %%
a3

# %%
a3[::2, 0, ::2]

# %%
import numpy as np

a1 = np.arange(10)

# %%
a1

# %%
a2 = np.arange(12).reshape(3, 4)
a2

# %%
a3 = np.arange(27).reshape(3, 3, 3)
a3

# %%
for i in a1:
    print(i)

# %%
for i in a2:
    print(i)

# %%
for i in a3:
    print(i)

# %%
for i in np.nditer(a3):
    print(i)

# %% [markdown]
# Reshaping

# %%
## 1) reshape
## 2) transpose
## 3) ravel

print(a2)
print()
np.transpose(a2)

# %%
a2.T

# %%
## ravel
a2.ravel()

# %%
a3.ravel()

# %% [markdown]
# Stacking

# %%
## Horizontal stacking

a4 = np.arange(12).reshape(3, 4)
a5 = np.arange(12, 24).reshape(3, 4)

print(a4)
print()
print(a5)

# %%
np.hstack((a4, a5))

# %%
np.hstack((a4, a5, a4))

# %%
## Vertical Stacking

np.vstack((a4, a5))

# %% [markdown]
# Spliting

# %%
## Horizontal Spiliting

a4

# %%
np.hsplit(a4, 2)

# %%
np.hsplit(a4, 4)

# %%
a5

# %%
np.vsplit(a5, 3)
